# %% [markdown]
# <a href="https://colab.research.google.com/github/ttnyoung/080223/blob/master/03_%5B%EB%B6%84%EC%84%9D%ED%99%98%EA%B2%BD%5D_Google_Colaboratory_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Chapter 1. 데이터 분석을 위한 준비**
# ---

# %% [markdown]
# <img src="data:image/jpeg;base64,..." width="250" height="100"/>

# %% [markdown]
# ## 1-7. 분석 환경 스펙 정보 확인

# %% [markdown]
# ### **운영체제 (OS)**

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %% [markdown]
# ### **CPU 사양**

# %%
# !head /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0

# %%
# !head /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0

# %% [markdown]
# ### **메모리(RAM) 사양**

# %%
# !head -n 3 /proc/meminfo
# Out:
# MemTotal:       13302920 kB
# MemFree:        10673380 kB
# MemAvailable:   12425580 kB

# %%
# !head -n 3 /proc/meminfo
# Out:
# MemTotal:       13302920 kB
# MemFree:        10592208 kB
# MemAvailable:   12276504 kB

# %% [markdown]
# 13Ga

# %% [markdown]
# ### **Python 버전**

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
# !python --version
# Out:
# Python 3.7.13

# %% [markdown]
# ### **GPU 사용하기**
# > - 상단 `수정` > `노트 설정` > `하드웨어 가속기` >`GPU`
# > - 코랩 GPU는 12시간 동안 무료로 사용 가능

# %%
# !nvidia-smi
# Out:
# Thu Apr  7 01:43:00 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P8    13W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvidia-smi
# Out:
# Thu Apr  7 07:57:29 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## 1-8. 드라이브 마운트하기

# %% [markdown]
# ### **UI 를 이용하는 방법**
# > - 좌측 폴더 아이콘 클릭
# > - 상단 구글 드라이브 아이콘 클릭

# %% [markdown]
# ### **코드를 이용하는 방법**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1-9. 파일 업로드 하기

# %% [markdown]
# ### **파일 탐색기 업로드 방법**

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-21ab954a-cf6a-4432-abfb-f01996f69e0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21ab954a-cf6a-4432-abfb-f01996f69e0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample.csv to sample (1).csv

# %%
import io
import pandas as pd
data = pd.read_csv(io.BytesIO(myfile['sample.csv']))
data
# Out:
#   awesome_table  column1  column2  column3
# 0          row1        1        1        1
# 1          row2        2        2        2
# 2          row3        3        3        3

# %% [markdown]
# ### **구글 드라이브에 직접 업로드 방법 (추천)**
# > - 구글 드라이브에 파일 직접 올리기
# > - 경로 복사 후 파일 읽기

# %%
filepath = '/content/drive/MyDrive/00_fastcampus/01_google_colab/sample.csv'

# %%
import pandas as pd
data = pd.read_csv(filepath)
data
# Out:
#   awesome_table  column1  column2  column3
# 0          row1        1        1        1
# 1          row2        2        2        2
# 2          row3        3        3        3

# %%
import pandas as pd
data = pd.read_csv("sample.csv")
data
# Out:
#   awesome_table  column1  column2  column3
# 0          row1        1        1        1
# 1          row2        2        2        2
# 2          row3        3        3        3

# %% [markdown]
# ## 1-10. Colab sha하기

# %% [markdown]
# ### **공유 보내기**
# > - 우측 상단 `공유` 버튼 클릭
#   - 이메일을 통한 공유 초대
#   - 링크 전달을 통한 공유
# > - 읽기 전용 공유 방법 : 사용자 선택 우측 (편집자 -> 뷰어) 로 변경해서 공유

# %% [markdown]
# ### **공유 받기**
# >  - 이메일 공유 수락
# >  - 전달 받은 링크 주소로 접속

# %%
print('공유 받기 완료!')
# Out:
# 공유 받기 완료!

# %%
print('공유 받기 완료!')
# Out:
# 공유 받기 완료!
